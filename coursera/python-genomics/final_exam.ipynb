# %%
def read_fasta(fname):
    headers, records = [], []
    record = ""
    with open(fname, "rb") as fin:
        for line in fin:
            if not line[0] == '>':
                record += line.strip()
            else:
                headers.append(line.strip())
                if record:
                    records.append(record)
                    record = ""
    if record:
        records.append(record)
    return headers, records

# %%
def get_frame(genome, start):
    # frame 1: ATG ATG
    # frame 2: A TGA TG
    # frame 3: AT GAT G
    frame, n = [], len(genome)
    for i in range(start, n, 3):
        if (i + 3) <= n:
            frame.append(genome[i:i + 3])
    return frame

def get_orfs(genome, start):
    START_CODON = "ATG"
    END_CODONS = ["TAA", "TAG", "TGA"]
    orfs = []
    frame = get_frame(genome, start)
    for i in range(len(frame)):
        if frame[i] == START_CODON:
            for j in range(i + 1, len(frame)):
                if frame[j] in END_CODONS:
                    orfs.append("".join(frame[i:j+1]))
    return orfs

print get_orfs("ATGAAATAG", 0)

def get_ngram_positions(genome, n):
    """
    n - length of the repeats
    """
    ngrams = {}
    for i in range(len(genome) - n + 1):
        ngram = genome[i:i+n]
        if ngram not in ngrams:
            ngrams[ngram] = set([i])
        else:
            ngrams[ngram].add(i)
    return ngrams
# Out:
# ['ATGAAATAG']

# %%
headers, records = read_fasta("dna2.fasta")
print 'record count:', len(headers)
print 'longest sequence', max([len(r) for r in records])
print 'sortest sequence', min([len(r) for r in records])
print
for i in range(len(headers)):
    print headers[i]
    print 'record length:', len(records[i])
    orfs = get_orfs(records[i], 2)
    ngrams = get_ngram_positions(records[i], 10)
    repeats = dict((key,value) for key, value in ngrams.iteritems() if len(value) > 1)
#     mlen, mstart = 0, 0
#     for start, orf in orfs:
#         if len(orf) > mlen:
#             mstart = start
#             mlen = len(orf)
    print 'max orf length:', max([len(orf) for orf in orfs] or [0])
#     print 'max orf start:', mstart
    print 'repeats of len 7:', len(repeats)
    print '*****************'
# Out:
# record count: 18
# longest sequence 4894
# sortest sequence 115
#
# >gi|142022655|gb|EQ086233.1|91 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 4635
# max orf length: 3678
# repeats of len 7: 68
# *****************
# >gi|142022655|gb|EQ086233.1|304 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 1151
# max orf length: 519
# repeats of len 7: 2
# *****************
# >gi|142022655|gb|EQ086233.1|255 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 4894
# max orf length: 3609
# repeats of len 7: 73
# *****************
# >gi|142022655|gb|EQ086233.1|45 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 3511
# max orf length: 3207
# repeats of len 7: 71
# *****************
# >gi|142022655|gb|EQ086233.1|396 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 4076
# max orf length: 3633
# repeats of len 7: 85
# *****************
# >gi|142022655|gb|EQ086233.1|250 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 2867
# max orf length: 1689
# repeats of len 7: 52
# *****************
# >gi|142022655|gb|EQ086233.1|322 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 442
# max orf length: 264
# repeats of len 7: 0
# *****************
# >gi|142022655|gb|EQ086233.1|88 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 890
# max orf length: 0
# repeats of len 7: 6
# *****************
# >gi|142022655|gb|EQ086233.1|594 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 967
# max orf length: 864
# repeats of len 7: 10
# *****************
# >gi|142022655|gb|EQ086233.1|293 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 4338
# max orf length: 2172
# repeats of len 7: 43
# *****************
# >gi|142022655|gb|EQ086233.1|75 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 1352
# max orf length: 591
# repeats of len 7: 7
# *****************
# >gi|142022655|gb|EQ086233.1|454 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 4564
# max orf length: 4320
# repeats of len 7: 104
# *****************
# >gi|142022655|gb|EQ086233.1|16 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 4804
# max orf length: 4557
# repeats of len 7: 114
# *****************
# >gi|142022655|gb|EQ086233.1|584 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 964
# max orf length: 537
# repeats of len 7: 0
# *****************
# >gi|142022655|gb|EQ086233.1|4 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 2095
# max orf length: 1395
# repeats of len 7: 16
# *****************
# >gi|142022655|gb|EQ086233.1|277 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 1432
# max orf length: 648
# repeats of len 7: 11
# *****************
# >gi|142022655|gb|EQ086233.1|346 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 115
# max orf length: 0
# repeats of len 7: 0
# *****************
# >gi|142022655|gb|EQ086233.1|527 marine metagenome JCVI_SCAF_1096627390048 genomic scaffold, whole genome shotgun sequence
# record length: 2646
# max orf length: 2625
# repeats of len 7: 21
# *****************

# %%
genome = "".join(records)
ngrams = get_ngram_positions(genome, 12)
repeats = [(key,len(value)) for key, value in ngrams.iteritems() if len(value) > 1]
print sorted(repeats, lambda x, y: y[1]-x[1])
# Out:
# [('ATTCGCCATTCG', 10), ('CATTCGCCATTC', 10), ('TTCGCCATTCGC', 10), ('TCGCCATTCGCC', 10), ('CCATTCGCCATT', 9), ('CGCCATTCGCCA', 9), ('GCCATTCGCCAT', 9), ('TCGGGCTGCCGT', 3), ('CGCGGTCGATGC', 3), ('CTCGCGCAGCGC', 3), ('GATCACCGCGAC', 3), ('CGCCGCGCGACG', 3), ('AGCGTCGCGAGC', 3), ('GCGCGCCGTCGC', 3), ('CAGGTCGCGCCG', 3), ('CGCGTTCAGCGC', 3), ('GCGGCGTCCGGC', 3), ('CGAGCACCGCGA', 3), ('GCGCGCCGCGTG', 3), ('CGCGCGCCGCGT', 3), ('GCCGCGCAGATC', 3), ('CGTGCGGATCAC', 3), ('CCGGCGCGGCCG', 3), ('CGCGACGCTCGC', 3), ('GCGCTGGCCGCG', 3), ('CGCTCGCGCAGC', 3), ('CGACGAGCTGGT', 3), ('GTGCGGATCACG', 3), ('GCGCAGATCGCG', 3), ('GCTCGCGCAGCG', 3), ('CGATCCTCGCCG', 3), ('GGTCGATGCGAT', 3), ('GCGCGCTGATCG', 3), ('GCGAAGGCCGCG', 3), ('GCCGCGCGACGC', 3), ('TGCTGCGCGACC', 3), ('CGCGCAGATCGC', 3), ('CCAGGTCGCGCC', 3), ('ATCGCGATGCGC', 3), ('TCGCGCCGAGCG', 3), ('CTGCTGCGCGCG', 3), ('GCGATCACCTGT', 2), ('CGCCGATCGACG', 2), ('TACGCGAGCGTG', 2), ('GCGCTCGCGCAG', 2), ('CGGCGAGATCGT', 2), ('GCCGTACGTCGA', 2), ('TGGCGCTCGCGG', 2), ('TCACGCCGAGGT', 2), ('GCTCGGCACGAC', 2), ('AAACGATCGCGG', 2), ('CCGAACGGCTGC', 2), ('TCGTGCGCGCCG', 2), ('CGCGCCGGGCGA', 2), ('GATCGTCGCGCT', 2), ('GATCGTCGCGCC', 2), ('CAGCGCGGCGGC', 2), ('CGGCGACGAGCC', 2), ('ACGGCAAGGGCA', 2), ('GCTGATCCTGTT', 2), ('AGCGCGGCGGCT', 2), ('CGGATCACCGCG', 2), ('CGGCATGGGGCG', 2), ('CGGCCGAGCTGA', 2), ('CCGACCACCAGC', 2), ('CGAGCGCGCCGG', 2), ('CGCGGTTCCGCG', 2), ('CGCTGGCCGTGC', 2), ('CGCCGCGTGATC', 2), ('CGAAGGCCGCGT', 2), ('CGCGACGCGCGA', 2), ('TCGCCGCCGCGC', 2), ('CGACCACCAGCA', 2), ('CGCGGCATCGCC', 2), ('TCGGCGTGTCGC', 2), ('GCGCGGCGGCTT', 2), ('CGATCAGGATCG', 2), ('TACAACGTCGGG', 2), ('ATCACCGCGACG', 2), ('TCGAGCAGCAGC', 2), ('GGCGCCGATGCC', 2), ('CGTGTCGCTGAT', 2), ('GGCCGAGCTGAT', 2), ('GATGCGCTCGAC', 2), ('ACGCGCGGCATC', 2), ('CGAAGTCGGCCT', 2), ('GCACTCAGCCGC', 2), ('CGATCGTCGCGC', 2), ('TCGAGCGCATCG', 2), ('CGGCTCGCGCCG', 2), ('CTCGCCGGGCAC', 2), ('TCGTCGGCGATC', 2), ('ATCACGAGCGTG', 2), ('CGCGCGGCAACG', 2), ('CGCGCAGTGTCG', 2), ('AGCCGCGACTGC', 2), ('GCCGAGCGCTTC', 2), ('CGGGCGGCTTCG', 2), ('ACGCTCGCGCAG', 2), ('GCTTCCAGTACC', 2), ('CGTGATGTGCGT', 2), ('TGCGCCGGCCGG', 2), ('GGTCGCCCGACG', 2), ('TCGGCTGGCGCG', 2), ('TGCGGCCGAAGC', 2), ('TCGACGAGCAGA', 2), ('GCGCGATCGCGC', 2), ('GCGTCGAACAGG', 2), ('CACGCACTTCGG', 2), ('CGATGATCGCGA', 2), ('GCGCTGGCGCGC', 2), ('ACGCCGCGCAGA', 2), ('GCGCTGCTGCGC', 2), ('TTGCTGCGCGAG', 2), ('AGGTCGCGCCGA', 2), ('GACGATGAACGA', 2), ('GCGCCGATCAGG', 2), ('CGCGATGCTGAA', 2), ('GCTGCGCGAGCA', 2), ('GCGCGGCGGCAC', 2), ('GACGCGCGGATG', 2), ('CGAGACGAAGCG', 2), ('ACGAGACGAAGC', 2), ('GACGTCGCCGAC', 2), ('GAACTCGGCGCG', 2), ('CCCGCCGCGATC', 2), ('GCGCGCGGCTTC', 2), ('CGCCGTCGAGCA', 2), ('ACTTGGCCGGCA', 2), ('GGCGACTTCGAC', 2), ('CCGACGCGCGGC', 2), ('GCGGCGCCGCGT', 2), ('GGGCTGTTCGGC', 2), ('CGCCGATGCCGA', 2), ('TGTCGCTGATCA', 2), ('CCACGACCGCGG', 2), ('CGGCGTGTCGAG', 2), ('ACAGCGTCGCGA', 2), ('GAATTCCGAATA', 2), ('CGGAGCTGATCG', 2), ('TTCGCGACGAGC', 2), ('GCGATCGTCGCG', 2), ('GCCGAGCACGTG', 2), ('GCGAGCGTGAAG', 2), ('GCCGGCGCGGCC', 2), ('TCGCGGCGCGCG', 2), ('GTCGGCGCGGTG', 2), ('ATGCGCTCGACA', 2), ('CGTGTCGTTCAG', 2), ('CGACGACGAGAT', 2), ('TCGCCGGGCACG', 2), ('GCATCGGGTTCG', 2), ('TGCGCGACGTCG', 2), ('CGCGATCGCGCC', 2), ('CGCGCGCAGTGT', 2), ('CGGTGACGCCCG', 2), ('GCGCGCTGCTGC', 2), ('CGGAAAACACCG', 2), ('GCTGCGCGACCG', 2), ('GATCACGTCGAC', 2), ('GCACGACGCGCG', 2), ('GGCCACGACCGC', 2), ('TGATCGCGGCCG', 2), ('CGGCGCGGCCGC', 2), ('CGCTCGCGTGGG', 2), ('AGCCGCACGCGC', 2), ('CAGCACCGGCGC', 2), ('TCACGAGCGTGA', 2), ('TCAGCGCCGGCA', 2), ('GCCTGCCGGACA', 2), ('CGAACTCGGCGC', 2), ('TGCGCGCCGATC', 2), ('TGCGCCCGGCCT', 2), ('CAGCGCGCGGCG', 2), ('GCCGCGCACGTG', 2), ('TCGCCGACATCG', 2), ('CGTCGTCGACCA', 2), ('GATGCGCTGGCG', 2), ('ACGACGTCGAGC', 2), ('TTGTCGTCGAGC', 2), ('GGCGCGCGCGGC', 2), ('CGCACGGCGGCT', 2), ('TCGGCATCCTGC', 2), ('TGCGCGCCGTCG', 2), ('CCGGCCTCGCGC', 2), ('GCGGGCGCGCTG', 2), ('GCAGCGCCGCGC', 2), ('GCGACGTTGCCG', 2), ('GCGTCGTGCGCG', 2), ('TGCTGATCCTGT', 2), ('GCC ...
